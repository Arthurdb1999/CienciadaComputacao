# %% [markdown]
# # Importação das bibliotecas

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
#import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff

# %% [markdown]
# ## Carregamento do Titanic Dataset

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %% [markdown]
# ### Visualização da variável "survived" com base na taxa

# %%
sns.catplot(x="survived", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "age" com base na taxa e no sexo

# %%
sns.catplot(x="age", y="fare", data=titanic, hue="sex")

# %% [markdown]
# ### Visualização da variável "pclass" com base na taxa

# %%
sns.catplot(x="pclass", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "sibsp" com base na taxa

# %%
sns.catplot(x="sibsp", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "parch" com base na taxa

# %%
sns.catplot(x="parch", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "embarked" com base na taxa

# %%
sns.catplot(x="embarked", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "class" com base na taxa

# %%
sns.catplot(x="class", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "who" com base na taxa

# %%
sns.catplot(x="who", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "adult_male" com base na taxa

# %%
sns.catplot(x="adult_male", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "deck" com base na taxa

# %%
sns.catplot(x="deck", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "embark_town" com base na taxa

# %%
sns.catplot(x="embark_town", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "alive" com base na taxa

# %%
sns.catplot(x="alive", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ### Visualização da variável "alone" com base na taxa

# %%
sns.catplot(x="alone", y="fare", data=titanic, kind="swarm")

# %% [markdown]
# ## Carregamento do Iris Dataset

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Visualização de sepal_length

# %%
sns.catplot(x="species", y="sepal_length", data=iris, kind="swarm")

# %% [markdown]
# ### Visualização de sepal_width

# %%
sns.catplot(x="species", y="sepal_width", data=iris, kind="swarm")

# %% [markdown]
# ### Visualização de petal_length

# %%
sns.catplot(x="species", y="petal_length", data=iris, kind="swarm")

# %% [markdown]
# ### Visualização de petal_width

# %%
sns.catplot(x="species", y="petal_width", data=iris, kind="swarm")

# %% [markdown]
# ### Relação entre sepal_length e petal_length

# %%
sns.relplot(x="sepal_length", y="petal_length", hue="species" ,data=iris)

# %% [markdown]
# ### Relação entre sepal_width e petal_width

# %%
sns.relplot(x="sepal_width", y="petal_width", hue="species" ,data=iris)

# %% [markdown]
# ### Relação entre sepal_length e sepal_width

# %%
sns.relplot(x="sepal_length", y="sepal_width", hue="species" ,data=iris)

# %% [markdown]
# ### Relação entre petal_length e petal_width

# %%
sns.relplot(x="petal_length", y="petal_width", hue="species" ,data=iris)

# %% [markdown]
# ### Relação entre sepal_length e petal_width

# %%
sns.relplot(x="sepal_length", y="petal_width", hue="species" ,data=iris)

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Visualização dos dados utilizando Facets

# %%
sns.catplot(x="petal_length", y="petal_width", hue="species", col="species", data=iris);

# %% [markdown]
# ### Primeiro modelo de Pairplot

# %%
sns.pairplot(iris)

# %% [markdown]
# ### Segundo modelo de Pairplot

# %%
sns.pairplot(iris, hue="species", kind="reg")
